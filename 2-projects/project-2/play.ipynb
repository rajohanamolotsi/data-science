# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df = pd.read_csv('test_scores.csv')

# %%
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
reg = linear_model.LinearRegression()

# %%
plt.scatter(df['math'], df['cs'])
plt.xlabel('MATH'), plt.ylabel('COMS')
plt.title('The relationship of acing MATH to COMS')
plt.tight_layout()

# %%
reg.fit(df[['math']], df['cs'])
# Out:
# LinearRegression()

# %%
reg.coef_, reg.intercept_
# Out:
# (array([1.01773624]), np.float64(1.9152193111568891))

# %% [markdown]
# - These results do not match the gradient descent ones
