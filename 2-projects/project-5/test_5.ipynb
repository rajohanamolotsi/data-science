# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df = pd.read_csv('insurance_data.csv')

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df['age'], df['bought_insurance'], marker='*', color='r')
plt.xlabel('Age')
plt.ylabel('Bought Insurance (1 or 0)')
plt.title('Age vs. Bought Insurance')
plt.tight_layout()

# %%
model = linear_model.LogisticRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=.3)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1, 1, 0, 1, 0, 0, 1])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#     age
# 18   19
# 24   50
# 25   54
# 8    62
# 13   29
# 4    46
# 19   18
# 10   18
# 15   55

# %%
model.predict_proba(X_test)
# Out:
# array([[0.89654988, 0.10345012],
#        [0.26179547, 0.73820453],
#        [0.19014625, 0.80985375],
#        [0.09331064, 0.90668936],
#        [0.7555541 , 0.2444459 ],
#        [0.34881444, 0.65118556],
#        [0.90572887, 0.09427113],
#        [0.90572887, 0.09427113],
#        [0.17477439, 0.82522561]])

# %%
model.predict([[22], [52], [39]])
# Out:
# array([0, 1, 0])
