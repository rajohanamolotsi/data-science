# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('canada_per_capita_income.csv')

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.scatter(df['year'], df['per capita income (US$)'])
plt.xlabel('Year')
plt.ylabel('Per capita income (US$)')
plt.title("Canada's Income Per Captica")
plt.tight_layout()

# %%
model = LinearRegression()

# %%
model.fit(df[['year']], df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
predicted_income = float(model.predict([[2020]]))
# Out:
# C:\Users\rajoh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\rajoh\AppData\Local\Temp\ipykernel_9824\424080376.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_income = float(model.predict([[2020]]))

# %%
plt.scatter(df['year'], df['per capita income (US$)'])
plt.scatter(2020, predicted_income, marker='*', color='r')
plt.xlabel('Year')
plt.ylabel('Per capita income (US$)')
plt.title("Canada's Income Per Captica")
plt.tight_layout()

# %%
predicted_income
# Out:
# 41288.69409441762

# %% [markdown]
# - Why do we thing this is a linear regresion?
#   - How can we really settle that arguement?
